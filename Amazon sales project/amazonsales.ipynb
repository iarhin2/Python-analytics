# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Amazon.csv')

# %%
df.shape
# Out:
# (60343, 20)

# %%
df.columns
# Out:
# Index(['OrderID', 'OrderDate', 'CustomerID', 'CustomerName', 'ProductID',
#        'ProductName', 'Category', 'Brand', 'Quantity', 'UnitPrice', 'Discount',
#        'Tax', 'ShippingCost', 'TotalAmount', 'PaymentMethod', 'OrderStatus',
#        'City', 'State', 'Country', 'SellerID'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60343 entries, 0 to 60342
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderID        60343 non-null  object
#  1   OrderDate      60343 non-null  object
#  2   CustomerID     60343 non-null  object
#  3   CustomerName   60342 non-null  object
#  4   ProductID      60342 non-null  object
#  5   ProductName    60342 non-null  object
#  6   Category       60342 non-null  object
#  7   Brand          60342 non-null  object
#  8   Quantity       60342 non-null  float64
#  9   UnitPrice      60342 non-null  float64
#  10  Discount       60342 non-null  float64
#  11  Tax            60342 non-null  float64
#  12  ShippingCost   60342 non-null  float64
#  13  TotalAmount    60342 non-null  float64
#  14  PaymentMethod  60342 non-null  object
#  15  OrderStatus    60342 non-null  object
#  16  City           60342 non-null  object
#  17  State          60342 non-null  object
#  18  Country        60342 non-null  object
#  19  SellerID       60342 non-null  object
# dtypes: float64(6), object(14)
# memory usage: 9.2+ MB

# %%
df.describe()
# Out:
#            Quantity     UnitPrice      Discount           Tax  ShippingCost  \
# count  60342.000000  60342.000000  60342.000000  60342.000000  60342.000000
# mean       2.997564    302.751269      0.074345     68.405687      7.384312
# std        1.413338    171.907923      0.082689     73.974054      4.322354
# min        1.000000      5.000000      0.000000      0.000000      0.000000
# 25%        2.000000    153.862500      0.000000     15.940000      3.650000
# 50%        3.000000    302.040000      0.050000     45.280000      7.270000
# 75%        4.000000    451.195000      0.100000     96.000000     11.120000
# max        5.000000    599.990000      0.300000    538.460000     15.000000
#
#         TotalAmount
# count  60342.000000
# mean     917.356977
# std      725.674389
# min        6.190000
# 25%      340.302500
# 50%      712.030000
# 75%     1342.717500
# max     3534.980000

# %%
df.head()
# Out:
#       OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0  ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1  ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2  ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
# 3  ORD0000004  2023-07-18  CUST030059   Vihaan Reddy    P00041
# 4  ORD0000005  2023-02-04  CUST048677  Aditya Kapoor    P00029
#
#            ProductName        Category       Brand  Quantity  UnitPrice  \
# 0           Drone Mini           Books   BrightLux       3.0     106.59
# 1           Microphone  Home & Kitchen  UrbanStyle       1.0     251.37
# 2  Power Bank 20000mAh        Clothing  UrbanStyle       3.0      35.03
# 3       Webcam Full HD  Home & Kitchen      Zenith       5.0      33.58
# 4              T-Shirt        Clothing    KiddoFun       2.0     515.64
#
#    Discount    Tax  ShippingCost  TotalAmount     PaymentMethod OrderStatus  \
# 0      0.00   0.00          0.09       319.86        Debit Card   Delivered
# 1      0.05  19.10          1.74       259.64        Amazon Pay   Delivered
# 2      0.10   7.57          5.91       108.06        Debit Card   Delivered
# 3      0.15  11.42          5.53       159.66  Cash on Delivery   Delivered
# 4      0.25  38.67          9.23       821.36       Credit Card   Cancelled
#
#           City State        Country   SellerID
# 0   Washington    DC          India  SELL01967
# 1   Fort Worth    TX  United States  SELL01298
# 2       Austin    TX  United States  SELL00908
# 3    Charlotte    NC          India  SELL01164
# 4  San Antonio    TX         Canada  SELL01411

# %%
# KPI analysis
# Total Sales
df['TotalAmount'].sum()
# Out:
# np.float64(55355154.7)

# %%
# Total Orders
df['OrderID'].count()
# Out:
# np.int64(60343)

# %%
# Average sales
df['TotalAmount'].mean()
# Out:
# np.float64(917.3569768983461)

# %%
# Maximum quantity
df['Quantity'].max()
# Out:
# 5.0

# %%
# Revenue by state
df.groupby('State')['TotalAmount'].sum().sort_values(ascending=False)
# Out:
# State
# TX    22862540.54
# CA    18231196.79
# NC     4747701.73
# WA     4660962.17
# PA     4650673.88
# CO     4638498.97
# IL     4632847.44
# OH     4615442.32
# IN     4609048.43
# FL     4597177.27
# NY     4554358.08
# DC     4520876.11
# AZ     4504324.19
# Name: TotalAmount, dtype: float64

# %%
# Revenue by category
df.groupby('Category')['TotalAmount'].sum().sort_values(ascending=False)
# Out:
# Category
# Electronics          15584217.18
# Sports & Outdoors    15345571.88
# Books                15261837.01
# Clothing             15253397.50
# Toys & Games         15216684.99
# Home & Kitchen       15163939.36
# Name: TotalAmount, dtype: float64

# %%
# Top 5 customers
df.groupby('CustomerName')['TotalAmount'].sum().sort_values(ascending=False).head(5)
# Out:
# CustomerName
# Pooja Kapoor    547832.64
# Vihaan Singh    526675.89
# Pooja Singh     516451.45
# Kabir Joshi     515361.68
# Aditya Gupta    515005.09
# Name: TotalAmount, dtype: float64

# %%
df.groupby('Category')['PaymentMethod'].value_counts()
# Out:
# Category           PaymentMethod
# Books              Credit Card         5939
#                    Debit Card          3354
#                    Amazon Pay          2599
#                    UPI                 2417
#                    Net Banking         1636
#                    Cash on Delivery     807
# Clothing           Credit Card         5811
#                    Debit Card          3298
#                    Amazon Pay          2479
#                    UPI                 2392
#                    Net Banking         1646
#                    Cash on Delivery     813
# Electronics        Credit Card         5900
#                    Debit Card          3409
#                    UPI                 2575
#                    Amazon Pay          2485
#                    Net Banking         1633
#                    Cash on Delivery     851
# Home & Kitchen     Credit Card         5766
#                    Debit Card          3318
#                    Amazon Pay          2517
#                    UPI                 2501
#                    Net Banking         1689
#                    Cash on Delivery     819
# Sports & Outdoors  Credit Card         5916
#                    Debit Card          3327
#                    UPI                 2567
#                    Amazon Pay          2487
#                    Net Banking         1645
#                    Cash on Delivery     862
# Toys & Games       Credit Card         5706
#                    Debit Card          3318
#                    UPI                 2614
#                    Amazon Pay          2450
#                    Net Banking         1678
#                    Cash on Delivery     776
# Name: count, dtype: int64

# %%
# Visualization
df.groupby('State')['TotalAmount'].sum().plot(kind='bar')
plt.title('Revenue by State')
plt.xlabel('State')
plt.ylabel('Revenue')
plt.show()

# %%
df.groupby(['CustomerID', 'CustomerName'])['TotalAmount'].sum().sort_values(ascending=False).head()
# Out:
# CustomerID  CustomerName
# CUST010696  Pooja Patel     5436.04
# CUST035973  Neha Sharma     5124.43
# CUST009614  Vikas Mehta     5003.65
# CUST018720  Arjun Kapoor    4773.18
# CUST022824  Pooja Joshi     4755.48
# Name: TotalAmount, dtype: float64

# %%
df.groupby('Category')['TotalAmount'].sum().plot(kind='pie')
plt.title('Revenue by Category')
plt.show()
